# %%
import requests
from bs4 import BeautifulSoup

from bs4.element import Comment
import pandas as pd
import numpy as np
import json
from bs4 import BeautifulSoup
from bs4.element import Tag, NavigableString
from urllib.request import urlopen

with open('index_to_link.json') as json_file:
    data = json.load(json_file)


def topic_info_extraction(data):
    
    # The dictionary to save all the topics
    my_dict = {}
    
    for index, link in data.items():
        
        # Checking progress
        if int(index) % 100 == 0:
            print(int(index))
    
        soup = BeautifulSoup(urlopen(link),"lxml")
        first_big_topic = ''
        round_value = 0

        topic_list = []

        for x in soup.find_all(["div"]):

            if "class" in x.attrs.keys() and x.attrs["class"] == ['position-relative', 'pt-1', 'pb-1', 'pl-4', 'ml-n2']:
                if x.get_text().replace("\n", "").strip() == first_big_topic:
                    break
                topic_list.append(x.get_text().replace("\n", "").strip())

                if round_value == 0:
                    first_big_topic = x.get_text().replace("\n", "").strip()
                    round_value += 1

            if "class" in x.attrs.keys() and 'position-relative' in x.attrs["class"] and 'pt-1' in x.attrs["class"] and 'pb-1' in x.attrs["class"] and len(x.attrs["class"]) == 4:
                topic_list.append("-" + x.get_text().replace("\n", "").strip())

            if "id" in x.attrs.keys() and 'speciality-container' in x.attrs["id"] and x.get_text():
                if x.get_text().replace("\n", "").strip() != '':
                    topic_list.append("--" + x.get_text().replace("\n", "").strip())

        my_dict[index] = topic_list
    
    print("Completed!")
    return my_dict

all_topics_dict = topic_info_extraction(data)

with open("all_topics.json", "w") as f:
    json.dump(all_topics_dict, f)
    f.close()
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# Completed!

# %%
with open('all_topics.json') as json_file:
    all_topics_dict = json.load(json_file)

# %%
#all_topics_dict

unique_big_topics = set()
unique_middle_topics = set()
unique_small_topics = set()

for index, topics in all_topics_dict.items():
    for topic in topics:
        if "-" not in topic:
            unique_big_topics.add(topic)
        elif "-" in topic and "--" not in topic:
            unique_middle_topics.add(topic)
        elif "--" in topic:
            unique_small_topics.add(topic)

# %%
print(f"Number of unique big topics: {len(unique_big_topics)}")
print(f"Number of unique middle topics: {len(unique_middle_topics)}") 
print(f"Number of unique small topics: {len(unique_small_topics)}")
# Out:
# Number of unique big topics: 11
# Number of unique middle topics: 121
# Number of unique small topics: 637

# %%
unique_big_topics
# Out:
# {'Business',
#  'Energy',
#  'Engineering',
#  'Fine Arts',
#  'Health and Medicine',
#  'Humanities',
#  'Mathematics',
#  'Science',
#  'Social Science',
#  'Society',
#  'Teaching and Education'}

# %%
unique_middle_topics
# Out:
# {'-Accounting',
#  '-Aerospace Engineering',
#  '-African American Studies',
#  '-Algebra and Number Theory',
#  '-Anatomy and Physiology',
#  '-Anthropology',
#  '-Applied Mathematics',
#  '-Archaeology',
#  '-Architecture',
#  '-Art History',
#  '-Asian Studies',
#  '-Biological Engineering',
#  '-Biology',
#  '-Biomedical Enterprise',
#  '-Biomedical Instrumentation',
#  '-Biomedical Signal and Image Processing',
#  '-Biomedicine',
#  '-Buildings',
#  '-Business',
#  '-Business Ethics',
#  '-Calculus',
#  '-Cancer',
#  '-Cellular and Molecular Medicine',
#  '-Chemical Engineering',
#  '-Chemistry',
#  '-Civil Engineering',
#  '-Climate',
#  '-Cognitive Science',
#  '-Combustion',
#  '-Communication',
#  '-Computation',
#  '-Computer Science',
#  '-Curriculum and Teaching',
#  '-Differential Equations',
#  '-Discrete Mathematics',
#  '-Earth Science',
#  '-Economics',
#  '-Education Policy',
#  '-Educational Technology',
#  '-Electrical Engineering',
#  '-Electricity',
#  '-Engineering',
#  '-Entrepreneurship',
#  '-Environmental Engineering',
#  '-Epidemiology',
#  '-European and Russian Studies',
#  '-Finance',
#  '-Fossil Fuels',
#  '-Fuel Cells',
#  '-Functional Genomics',
#  '-Game Design',
#  '-Game Theory',
#  '-Gender Studies',
#  '-Geography',
#  '-Global Poverty',
#  '-Globalization',
#  '-Health Care Management',
#  '-Health and Exercise Science',
#  '-Higher Education',
#  '-History',
#  '-Humanities',
#  '-Hydrogen and Alternatives',
#  '-Immunology',
#  '-Indigenous Studies',
#  '-Industrial Relations and Human Resource Management',
#  '-Information Technology',
#  '-Innovation',
#  '-Language',
#  '-Latin and Caribbean Studies',
#  '-Leadership',
#  '-Legal Studies',
#  '-Linear Algebra',
#  '-Linguistics',
#  '-Literature',
#  '-Management',
#  '-Marketing',
#  '-Materials Science and Engineering',
#  '-Mathematical Analysis',
#  '-Mathematical Logic',
#  '-Mechanical Engineering',
#  '-Media Studies',
#  '-Medical Imaging',
#  '-Mental Health',
#  '-Middle Eastern Studies',
#  '-Music',
#  '-Nanotechnology',
#  '-Nuclear',
#  '-Nuclear Engineering',
#  '-Ocean Engineering',
#  '-Operations Management',
#  '-Organizational Behavior',
#  '-Pathology and Pathophysiology',
#  '-Performance Arts',
#  '-Pharmacology and Toxicology',
#  '-Philosophy',
#  '-Physical Education and Recreation',
#  '-Physics',
#  '-Political Science',
#  '-Probability and Statistics',
#  '-Project Management',
#  '-Psychology',
#  '-Public Administration',
#  '-Public Health',
#  '-Real Estate',
#  '-Religion',
#  '-Renewables',
#  '-Sensory-Neural Systems',
#  '-Social Medicine',
#  '-Social Science',
#  '-Sociology',
#  '-Spectroscopy',
#  '-Speech Pathology',
#  '-Supply Chain Management',
#  '-Systems Engineering',
#  '-Technology',
#  '-The Developing World',
#  '-Topology and Geometry',
#  '-Transportation',
#  '-Urban Studies',
#  '-Visual Arts',
#  "-Women's Studies"}

# %%
unique_small_topics
# Out:
# {'--Academic Writing',
#  '--Academic WritingCreative WritingCriticismNonfiction Prose',
#  '--Academic WritingCreative WritingNonfiction Prose',
#  '--Academic WritingNonfiction Prose',
#  '--Academic WritingNonfiction ProsePeriodic LiteratureTechnical Writing',
#  '--Academic WritingNonfiction ProseTechnical Writing',
#  '--Academic WritingTechnical Writing',
#  '--Aerodynamics',
#  '--AerodynamicsAstrodynamics',
#  '--AerodynamicsAvionicsGuidance and Control Systems',
#  '--AerodynamicsStructural Mechanics',
#  '--African History',
#  '--African HistoryAmerican HistoryMedieval HistoryWorld History',
#  '--African HistoryAsian HistoryEuropean History',
#  '--African HistoryHistory of Science and Technology',
#  '--Algorithms and Data Structures',
#  '--Algorithms and Data StructuresArtificial Intelligence',
#  '--Algorithms and Data StructuresArtificial IntelligenceData Mining',
#  '--Algorithms and Data StructuresArtificial IntelligenceTheory of Computation',
#  '--Algorithms and Data StructuresComputer Design and EngineeringComputer Networks',
#  '--Algorithms and Data StructuresComputer Design and EngineeringTheory of Computation',
#  '--Algorithms and Data StructuresComputer Networks',
#  '--Algorithms and Data StructuresComputer NetworksCryptography',
#  '--Algorithms and Data StructuresComputer NetworksSoftware Design and Engineering',
#  '--Algorithms and Data StructuresComputer NetworksTheory of Computation',
#  '--Algorithms and Data StructuresCryptographyTheory of Computation',
#  '--Algorithms and Data StructuresData MiningSoftware Design and Engineering',
#  '--Algorithms and Data StructuresGraphics and Visualization',
#  '--Algorithms and Data StructuresGraphics and VisualizationProgramming Languages',
#  '--Algorithms and Data StructuresProgramming Languages',
#  '--Algorithms and Data StructuresProgramming LanguagesSoftware Design and Engineering',
#  '--Algorithms and Data StructuresSoftware Design and Engineering',
#  '--Algorithms and Data StructuresTheory of Computation',
#  '--American History',
#  '--American HistoryAsian HistoryModern HistoryWorld History',
#  '--American HistoryComparative HistoryHistorical MethodsModern History',
#  '--American HistoryEuropean History',
#  '--American HistoryEuropean HistoryWorld History',
#  '--American HistoryHistoriographyHistory of Science and Technology',
#  '--American HistoryHistory of Science and Technology',
#  '--American HistoryHistory of Science and TechnologyModern History',
#  '--American HistoryMiddle Eastern HistoryModern History',
#  '--American HistoryMilitary History',
#  '--American HistoryModern History',
#  '--American Literature',
#  '--American LiteratureClassics',
#  '--American LiteratureClassicsComedyCreative WritingFiction',
#  '--American LiteratureClassicsComparative LiteratureCriticismFictionPeriodic Literature',
#  '--American LiteratureComparative LiteratureCreative WritingCriticismFiction',
#  '--American LiteratureComparative LiteratureCriticism',
#  '--American LiteratureComparative LiteratureCriticismFiction',
#  '--American LiteratureComparative LiteratureInternational Literature',
#  '--American LiteratureCreative WritingFiction',
#  '--American LiteratureCreative WritingNonfiction Prose',
#  '--American LiteratureCriticism',
#  '--American LiteratureCriticismFiction',
#  '--American LiteratureCriticismPoetry',
#  '--American Politics',
#  '--American PoliticsComparative Politics',
#  '--American PoliticsInternational Relations',
#  '--Analytical Chemistry',
#  '--Analytical ChemistryOrganic Chemistry',
#  '--Analytical ChemistryOrganic ChemistryPhysical Chemistry',
#  '--Analytical ChemistryPhysical Chemistry',
#  '--Ancient History',
#  '--Ancient HistoryAsian History',
#  '--Ancient HistoryEuropean History',
#  '--Ancient HistoryHistory of Science and Technology',
#  '--Ancient HistoryIntellectual History',
#  '--Aquatic Sciences and Water Quality Control',
#  '--Aquatic Sciences and Water Quality ControlEnvironmental ManagementHydrodynamics and Coastal Engineering',
#  '--Aquatic Sciences and Water Quality ControlEnvironmental ManagementHydrology and Water Resource Systems',
#  '--Aquatic Sciences and Water Quality ControlHydrodynamics and Coastal EngineeringHydrology and Water Resource Systems',
#  '--Aquatic Sciences and Water Quality ControlHydrology and Water Resource Systems',
#  '--Architectural Design',
#  '--Architectural DesignArchitectural Engineering',
#  '--Architectural DesignArchitectural EngineeringEnvironmental Design',
#  '--Architectural DesignArchitectural History and Criticism',
#  '--Architectural DesignArchitectural History and CriticismEnvironmental Design',
#  '--Architectural DesignArchitectural History and CriticismReligious Architecture',
#  '--Architectural DesignEnvironmental Design',
#  '--Architectural Engineering',
#  '--Architectural EngineeringArchitectural History and Criticism',
#  '--Architectural EngineeringEnvironmental Design',
#  '--Architectural History and Criticism',
#  '--Architectural History and CriticismReligious Architecture',
#  '--Artificial Intelligence',
#  '--Artificial IntelligenceComputer Design and Engineering',
#  '--Artificial IntelligenceData Mining',
#  '--Artificial IntelligenceData MiningSoftware Design and Engineering',
#  '--Artificial IntelligenceGraphics and Visualization',
#  '--Artificial IntelligenceGraphics and VisualizationSoftware Design and Engineering',
#  '--Artificial IntelligenceHuman-Computer Interfaces',
#  '--Artificial IntelligenceHuman-Computer InterfacesSoftware Design and Engineering',
#  '--Artificial IntelligenceProgramming Languages',
#  '--Artificial IntelligenceProgramming LanguagesSoftware Design and Engineering',
#  '--Artificial IntelligenceSoftware Design and Engineering',
#  '--Artificial IntelligenceTheory of Computation',
#  '--Asian History',
#  '--Asian HistoryComparative HistoryEuropean HistoryMedieval History',
#  '--Asian HistoryEuropean History',
#  '--Asian HistoryMedieval History',
#  '--Asian HistoryMilitary HistoryModern History',
#  '--Asian HistoryModern History',
#  '--Asian HistoryModern HistoryWorld History',
#  '--AstrodynamicsGuidance and Control Systems',
#  '--AstrodynamicsGuidance and Control SystemsPropulsion Systems',
#  '--Astrophysics',
#  '--AstrophysicsHigh Energy PhysicsNuclear Physics',
#  '--AstrophysicsRelativity',
#  '--AstrophysicsTheoretical Physics',
#  '--Atmospheric Science',
#  '--Atmospheric ScienceClimate Studies',
#  '--Atmospheric ScienceClimate StudiesEnvironmental Science',
#  '--Atmospheric ScienceClimate StudiesEnvironmental ScienceGeophysicsOceanography',
#  '--Atmospheric ScienceClimate StudiesEnvironmental ScienceSustainability',
#  '--Atmospheric ScienceClimate StudiesGeochemistryGeophysicsPlanetary Science',
#  '--Atmospheric ScienceClimate StudiesGeophysics',
#  '--Atmospheric ScienceClimate StudiesGeophysicsOceanography',
#  '--Atmospheric ScienceClimate StudiesOceanography',
#  '--Atmospheric ScienceEnvironmental Science',
#  '--Atmospheric ScienceGeochemistryGeophysics',
#  '--Atmospheric ScienceGeologyPlanetary Science',
#  '--Atmospheric ScienceGeophysics',
#  '--Atmospheric ScienceGeophysicsOceanography',
#  '--Atmospheric ScienceGeophysicsPlanetary Science',
#  '--Atmospheric ScienceOceanography',
#  '--Atmospheric ScienceOceanographyPlanetary Science',
#  '--Atomic, Molecular, Optical Physics',
#  '--Atomic, Molecular, Optical PhysicsClassical MechanicsElectromagnetism',
#  '--Atomic, Molecular, Optical PhysicsCondensed Matter Physics',
#  '--Atomic, Molecular, Optical PhysicsElectromagnetism',
#  '--Atomic, Molecular, Optical PhysicsElectromagnetismQuantum Mechanics',
#  '--Atomic, Molecular, Optical PhysicsQuantum Mechanics',
#  '--Avionics',
#  '--AvionicsGuidance and Control Systems',
#  '--Bioastronautics',
#  '--Biochemistry',
#  '--BiochemistryBiophysicsComputation and Systems Biology',
#  '--BiochemistryCell BiologyDevelopmental BiologyGeneticsMolecular Biology',
#  '--BiochemistryCell BiologyGeneticsMicrobiologyMolecular BiologyVirology',
#  '--BiochemistryCell BiologyGeneticsMolecular Biology',
#  '--BiochemistryCell BiologyMolecular Biology',
#  '--BiochemistryCell BiologyProteomicsVirology',
#  '--BiochemistryCell BiologyStem Cells',
#  '--BiochemistryComputation and Systems BiologyEcologyMolecular Biology',
#  '--BiochemistryMicrobiology',
#  '--BiochemistryMicrobiologyMolecular Biology',
#  '--BiochemistryMolecular Biology',
#  '--BiochemistryNeurobiology',
#  '--BiochemistryStructural Biology',
#  '--Biography',
#  '--BiographyCriticismNonfiction Prose',
#  '--Biological Anthropology',
#  '--Biological AnthropologyCultural AnthropologyEthnographySocial Anthropology',
#  '--Biomaterials',
#  '--BiomaterialsBiomechanics',
#  '--BiomaterialsBiomechanicsCell and Tissue Engineering',
#  '--BiomaterialsBiostatistics',
#  '--BiomaterialsBiotechnology',
#  '--BiomaterialsBiotechnologySynthetic Biology',
#  '--BiomaterialsCell and Tissue Engineering',
#  '--Biomechanics',
#  '--BiomechanicsCell and Tissue Engineering',
#  '--BiomechanicsComputational Biology',
#  '--Biophysics',
#  '--BiophysicsCell BiologyDevelopmental Biology',
#  '--BiophysicsCell BiologyMolecular Biology',
#  '--BiophysicsComputation and Systems Biology',
#  '--BiophysicsComputation and Systems BiologyMolecular Biology',
#  '--BiophysicsMolecular Biology',
#  '--BiophysicsNeuroscience',
#  '--Biostatistics',
#  '--Biotechnology',
#  '--BiotechnologyComputational Biology',
#  '--BiotechnologySynthetic Biology',
#  '--Cell Biology',
#  '--Cell BiologyComputation and Systems Biology',
#  '--Cell BiologyComputation and Systems BiologyEcologyMicrobiology',
#  '--Cell BiologyComputation and Systems BiologyMolecular Biology',
#  '--Cell BiologyDevelopmental BiologyGeneticsMolecular Biology',
#  '--Cell BiologyDevelopmental BiologyStem Cells',
#  '--Cell BiologyGenetics',
#  '--Cell BiologyGeneticsMicrobiologyMolecular BiologyVirology',
#  '--Cell BiologyGeneticsMolecular Biology',
#  '--Cell BiologyGeneticsNeurobiologyNeuroscience',
#  '--Cell BiologyMicrobiologyMolecular Biology',
#  '--Cell BiologyMicrobiologyMolecular BiologyVirology',
#  '--Cell BiologyMolecular Biology',
#  '--Cell BiologyMolecular BiologyNeurobiology',
#  '--Cell BiologyMolecular BiologyVirology',
#  '--Cell BiologyNeurobiologyNeuroscience',
#  '--Cell and Tissue Engineering',
#  '--Chinese',
#  '--Classical Mechanics',
#  '--Classical MechanicsElectromagnetism',
#  '--Classical MechanicsQuantum Mechanics',
#  '--Classical MechanicsThermodynamics',
#  '--Classics',
#  '--ClassicsComparative Literature',
#  '--ClassicsComparative LiteratureInternational Literature',
#  '--ClassicsComparative LiteratureInternational LiteraturePoetry',
#  '--ClassicsCriticismDramaFiction',
#  '--ClassicsCriticismNonfiction ProseRhetoric',
#  '--ClassicsDramaInternational Literature',
#  '--ClassicsFiction',
#  '--ClassicsInternational Literature',
#  '--ClassicsInternational LiteraturePoetry',
#  '--Climate Studies',
#  '--Climate StudiesEnvironmental Science',
#  '--Climate StudiesEnvironmental ScienceSustainability',
#  '--Climate StudiesGeochemistryGeologyOceanography',
#  '--Climate StudiesSustainability',
#  '--Comedy',
#  '--ComedyComparative LiteratureInternational Literature',
#  '--Community Development',
#  '--Community DevelopmentSocial Justice',
#  '--Comparative History',
#  '--Comparative HistoryEuropean HistoryWorld History',
#  '--Comparative HistoryHistorical MethodsHistoriography',
#  '--Comparative HistoryHistorical MethodsHistoriographyModern History',
#  '--Comparative HistoryMilitary History',
#  '--Comparative HistoryModern HistoryWorld History',
#  '--Comparative Literature',
#  '--Comparative LiteratureCreative WritingFictionInternational Literature',
#  '--Comparative LiteratureCriticism',
#  '--Comparative LiteratureCriticismDrama',
#  '--Comparative LiteratureCriticismDramaFiction',
#  '--Comparative LiteratureCriticismFiction',
#  '--Comparative LiteratureCriticismFictionInternational Literature',
#  '--Comparative LiteratureCriticismInternational Literature',
#  '--Comparative LiteratureCriticismInternational LiteraturePoetry',
#  '--Comparative LiteratureCriticismPeriodic Literature',
#  '--Comparative LiteratureCriticismPoetry',
#  '--Comparative LiteratureDrama',
#  '--Comparative LiteratureDramaInternational Literature',
#  '--Comparative LiteratureFiction',
#  '--Comparative LiteratureFictionPeriodic Literature',
#  '--Comparative LiteratureInternational Literature',
#  '--Comparative Politics',
#  '--Comparative PoliticsInternational Relations',
#  '--Composite MaterialsPolymeric Materials',
#  '--Computation and Systems Biology',
#  '--Computation and Systems BiologyEcology',
#  '--Computation and Systems BiologyGenetics',
#  '--Computation and Systems BiologyMolecular Biology',
#  '--Computation and Systems BiologyNeuroscience',
#  '--Computational Biology',
#  '--Computational BiologySynthetic Biology',
#  '--Computational Modeling and Simulation',
#  '--Computational Modeling and SimulationNumerical Simulation',
#  '--Computational Modeling and SimulationSystems Design',
#  '--Computational Modeling and SimulationSystems Optimization',
#  '--Computational Science and Engineering',
#  '--Computational Science and EngineeringNumerical Simulation',
#  '--Computational Science and EngineeringSystems Design',
#  '--Computational Science and EngineeringSystems Optimization',
#  '--Computer Design and Engineering',
#  '--Computer Design and EngineeringComputer Networks',
#  '--Computer Design and EngineeringComputer NetworksOperating SystemsSoftware Design and Engineering',
#  '--Computer Design and EngineeringSoftware Design and Engineering',
#  '--Computer Design and EngineeringTheory of Computation',
#  '--Computer Networks',
#  '--Computer NetworksCryptography',
#  '--Computer NetworksData Mining',
#  '--Computer NetworksSoftware Design and Engineering',
#  '--Condensed Matter Physics',
#  '--Condensed Matter PhysicsElectromagnetism',
#  '--Condensed Matter PhysicsElectromagnetismQuantum Mechanics',
#  '--Condensed Matter PhysicsNuclear Physics',
#  '--Condensed Matter PhysicsParticle PhysicsQuantum MechanicsRelativityTheoretical Physics',
#  '--Construction Management',
#  '--Creative Writing',
#  '--Creative WritingCriticismDrama',
#  '--Creative WritingCriticismFiction',
#  '--Creative WritingCriticismFictionNonfiction Prose',
#  '--Creative WritingCriticismNonfiction Prose',
#  '--Creative WritingCriticismPoetry',
#  '--Creative WritingDrama',
#  '--Creative WritingFiction',
#  '--Creative WritingFictionNonfiction Prose',
#  '--Creative WritingNonfiction ProsePoetry',
#  '--Criticism',
#  '--CriticismDrama',
#  '--CriticismDramaFictionPoetry',
#  '--CriticismDramaPoetryRhetoric',
#  '--CriticismFiction',
#  '--CriticismFictionInternational Literature',
#  '--CriticismFictionInternational LiteraturePoetry',
#  '--CriticismFictionPoetry',
#  '--CriticismInternational Literature',
#  '--CriticismInternational LiteraturePoetry',
#  '--CriticismNonfiction ProseRhetoric',
#  '--CriticismNonfiction ProseRhetoricTechnical Writing',
#  '--CriticismPoetry',
#  '--Cryptography',
#  '--CryptographyTheory of Computation',
#  '--Cultural Anthropology',
#  '--Cultural AnthropologyEthnography',
#  '--Cultural AnthropologyEthnographySocial Anthropology',
#  '--Cultural AnthropologySocial Anthropology',
#  '--Dance',
#  '--Data Mining',
#  '--Data MiningGraphics and Visualization',
#  '--Data MiningSoftware Design and Engineering',
#  '--Developmental Biology',
#  '--Developmental BiologyGeneticsMolecular Biology',
#  '--Developmental BiologyGeneticsStem Cells',
#  '--Developmental BiologyNeurobiology',
#  '--Developmental Economics',
#  '--Developmental EconomicsEconometricsMacroeconomicsMicroeconomics',
#  '--Developmental EconomicsIndustrial OrganizationInternational DevelopmentPublic Economics',
#  '--Developmental EconomicsInternational Development',
#  '--Developmental EconomicsInternational EconomicsPolitical Economy',
#  '--Developmental EconomicsMacroeconomics',
#  '--Developmental EconomicsMicroeconomics',
#  '--Developmental EconomicsMicroeconomicsPolitical Economy',
#  '--Developmental EconomicsPolitical Economy',
#  '--Developmental EconomicsPublic Economics',
#  '--Digital Media',
#  '--Digital Systems',
#  '--Digital SystemsElectronics',
#  '--Digital SystemsElectronicsRobotics and Control Systems',
#  '--Digital SystemsElectronicsSignal Processing',
#  '--Digital SystemsRobotics and Control SystemsSignal Processing',
#  '--Digital SystemsSignal Processing',
#  '--Digital SystemsSignal ProcessingTelecommunications',
#  '--Digital SystemsTelecommunications',
#  '--Drama',
#  '--Dynamics and Control',
#  '--Dynamics and ControlFluid MechanicsMechanical Design',
#  '--Dynamics and ControlMechanical Design',
#  '--Dynamics and ControlSolid Mechanics',
#  '--Ecology',
#  '--EcologyMolecular Biology',
#  '--Econometrics',
#  '--EconometricsFinancial Economics',
#  '--EconometricsLabor EconomicsMicroeconomics',
#  '--EconometricsMacroeconomics',
#  '--EconometricsMicroeconomics',
#  '--EconometricsPublic Economics',
#  '--Electric Power',
#  '--Electric PowerElectronics',
#  '--Electromagnetism',
#  '--ElectromagnetismHigh Energy PhysicsNuclear Physics',
#  '--ElectromagnetismNuclear Physics',
#  '--ElectromagnetismParticle PhysicsRelativity',
#  '--ElectromagnetismParticle PhysicsThermodynamics',
#  '--ElectromagnetismQuantum Mechanics',
#  '--ElectromagnetismTheoretical Physics',
#  '--ElectromagnetismThermodynamics',
#  '--Electronic Materials',
#  '--Electronics',
#  '--ElectronicsRobotics and Control Systems',
#  '--ElectronicsSignal Processing',
#  '--ElectronicsSignal ProcessingTelecommunications',
#  '--English as a Second Language',
#  '--Environmental Design',
#  '--Environmental Management',
#  '--Environmental Policy',
#  '--Environmental PolicyPublic Policy',
#  '--Environmental PolicyPublic PolicyRegional PoliticsScience and Technology PolicySocial Welfare',
#  '--Environmental PolicyPublic PolicyScience and Technology Policy',
#  '--Environmental PolicyScience and Technology Policy',
#  '--Environmental Science',
#  '--Environmental ScienceGeochemistry',
#  '--Environmental ScienceGeochemistryGeologyGeophysicsPlanetary Science',
#  '--Environmental ScienceGeochemistryGeologyPlanetary Science',
#  '--Environmental ScienceGeologyGeophysics',
#  '--Environmental ScienceGeologyGeophysicsPlanetary Science',
#  '--Environmental ScienceOceanography',
#  '--Environmental ScienceSustainability',
#  '--Epistemology',
#  '--EpistemologyEthicsLogicMetaphysics',
#  '--Ethics',
#  '--EthicsPolitical Philosophy',
#  '--Ethnography',
#  '--EthnographySocial Anthropology',
#  '--European History',
#  '--European HistoryHistorical MethodsMedieval History',
#  '--European HistoryHistory of Science and Technology',
#  '--European HistoryHistory of Science and TechnologyIntellectual History',
#  '--European HistoryIntellectual History',
#  '--European HistoryIntellectual HistoryMedieval History',
#  '--European HistoryLatin American History',
#  '--European HistoryMedieval History',
#  '--European HistoryMilitary History',
#  '--European HistoryModern History',
#  '--Fiction',
#  '--FictionInternational Literature',
#  '--Film and Video',
#  '--Film and VideoGraphic Design',
#  '--Film and VideoPhotography',
#  '--Financial Economics',
#  '--Financial EconomicsInternational Development',
#  '--Financial EconomicsInternational EconomicsMacroeconomics',
#  '--Financial EconomicsLabor EconomicsMacroeconomics',
#  '--Financial EconomicsMacroeconomicsPolitical Economy',
#  '--Fluid Mechanics',
#  '--Fluid MechanicsMechanical Design',
#  '--Fluid MechanicsSolid Mechanics',
#  '--French',
#  '--Genetics',
#  '--GeneticsMicrobiology',
#  '--GeneticsMicrobiologyMolecular Biology',
#  '--GeneticsMolecular Biology',
#  '--GeneticsNeurobiology',
#  '--GeneticsNeuroscience',
#  '--GeneticsProteomics',
#  '--GeneticsStructural Biology',
#  '--Geobiology',
#  '--GeobiologyGeochemistry',
#  '--GeobiologyGeochemistryGeology',
#  '--GeobiologyGeochemistryOceanography',
#  '--GeobiologyGeochemistryPlanetary Science',
#  '--Geochemistry',
#  '--GeochemistryGeology',
#  '--GeochemistryGeologyGeophysics',
#  '--GeochemistryGeologyGeophysicsOceanography',
#  '--GeochemistryOceanography',
#  '--Geology',
#  '--GeologyGeophysics',
#  '--GeologyGeophysicsPlanetary Science',
#  '--GeologyPlanetary Science',
#  '--Geophysics',
#  '--GeophysicsOceanography',
#  '--GeophysicsPlanetary Science',
#  '--Geotechnical Engineering',
#  '--Geotechnical EngineeringStructural Engineering',
#  '--German',
#  '--Graphic Design',
#  '--Graphic DesignPhotography',
#  '--Graphics and Visualization',
#  '--Graphics and VisualizationProgramming Languages',
#  '--Graphics and VisualizationSoftware Design and Engineering',
#  '--Guidance and Control Systems',
#  '--Guidance and Control SystemsPropulsion Systems',
#  '--High Energy PhysicsNuclear Physics',
#  '--High Energy PhysicsNuclear PhysicsParticle Physics',
#  '--High Energy PhysicsParticle Physics',
#  '--High Energy PhysicsParticle PhysicsRelativityTheoretical Physics',
#  '--Historical Methods',
#  '--Historical MethodsHistoriography',
#  '--Historical MethodsHistory of Science and Technology',
#  '--Historiography',
#  '--HistoriographyMiddle Eastern History',
#  '--HistoriographyModern History',
#  '--History of Science and Technology',
#  '--History of Science and TechnologyIntellectual History',
#  '--History of Science and TechnologyMilitary History',
#  '--History of Science and TechnologyMilitary HistoryModern History',
#  '--History of Science and TechnologyModern History',
#  '--History of Science and TechnologyModern HistoryWorld History',
#  '--History of Science and TechnologyWorld History',
#  '--Housing Development',
#  '--Housing DevelopmentRegional PlanningTransportation PlanningUrban Planning',
#  '--Housing DevelopmentRegional PlanningUrban Planning',
#  '--Housing DevelopmentUrban Planning',
#  '--Human-Computer Interfaces',
#  '--Human-Computer InterfacesProgramming LanguagesTheory of Computation',
#  '--Human-Computer InterfacesSoftware Design and Engineering',
#  '--Hydrodynamics',
#  '--Hydrodynamics and Coastal Engineering',
#  '--HydrodynamicsOcean Structures',
#  '--Hydrology and Water Resource Systems',
#  '--Industrial Organization',
#  '--Industrial OrganizationInternational Development',
#  '--Industrial OrganizationInternational Economics',
#  '--Industrial OrganizationInternational EconomicsMacroeconomics',
#  '--Industrial OrganizationLabor Economics',
#  '--Industrial OrganizationMacroeconomics',
#  '--Industrial OrganizationMicroeconomics',
#  '--Industrial OrganizationPublic Economics',
#  '--Inorganic Chemistry',
#  '--Inorganic ChemistryOrganic ChemistryPhysical Chemistry',
#  '--Intellectual History',
#  '--Intellectual HistoryModern History',
#  '--International Development',
#  '--International Economics',
#  '--International EconomicsMacroeconomics',
#  '--International EconomicsPolitical Economy',
#  '--International Literature',
#  '--International LiteratureNonfiction Prose',
#  '--International Relations',
#  '--Italian',
#  '--Japanese',
#  '--Jewish History',
#  '--Jewish HistoryMiddle Eastern HistoryModern History',
#  '--Labor Economics',
#  '--Labor EconomicsPolitical Economy',
#  '--Latin American History',
#  '--Latin American HistoryModern History',
#  '--Logic',
#  '--Macroeconomics',
#  '--MacroeconomicsMicroeconomics',
#  '--MacroeconomicsPolitical Economy',
#  '--MacroeconomicsPolitical EconomyPublic Economics',
#  '--Materials SelectionStructural Mechanics',
#  '--Mechanical Design',
#  '--Mechanical DesignMicrotechnology',
#  '--Mechanical DesignSolid Mechanics',
#  '--Medieval History',
#  '--Metallurgical Engineering',
#  '--Metaphysics',
#  '--Microbiology',
#  '--MicrobiologyMolecular Biology',
#  '--Microeconomics',
#  '--MicroeconomicsPolitical Economy',
#  '--Microtechnology',
#  '--Middle Eastern History',
#  '--Middle Eastern HistoryModern History',
#  '--Middle Eastern HistoryWorld History',
#  '--Military History',
#  '--Military Studies',
#  '--Military StudiesPublic Policy',
#  '--Military StudiesPublic PolicyRegional Politics',
#  '--Military StudiesPublic PolicySecurity Studies',
#  '--Military StudiesScience and Technology PolicySecurity Studies',
#  '--Military StudiesSecurity Studies',
#  '--Modern History',
#  '--Molecular Biology',
#  '--Molecular BiologyNeurobiology',
#  '--Molecular BiologyNeurobiologyNeuroscience',
#  '--Molecular BiologyStructural Biology',
#  '--Molecular Engineering',
#  '--Molecular EngineeringPolymersProcess Control Systems',
#  '--Music History',
#  '--Music HistoryMusic Performance',
#  '--Music HistoryMusic PerformanceMusic Theory',
#  '--Music HistoryMusic Theory',
#  '--Music Performance',
#  '--Music PerformanceMusic Theory',
#  '--Music Theory',
#  '--Neurobiology',
#  '--NeurobiologyNeuroscience',
#  '--Neuroscience',
#  '--Nonfiction Prose',
#  '--Nonfiction ProsePeriodic LiteratureRhetoric',
#  '--Nonfiction ProseRhetoric',
#  '--Nuclear Materials',
#  '--Nuclear MaterialsNuclear Systems, Policy, and Economics',
#  '--Nuclear Physics',
#  '--Nuclear PhysicsParticle Physics',
#  '--Nuclear PhysicsQuantum Mechanics',
#  '--Nuclear Systems, Policy, and Economics',
#  '--Numerical Simulation',
#  '--Ocean Exploration',
#  '--Ocean Structures',
#  '--Oceanic Pollution Control',
#  '--Oceanography',
#  '--Operating SystemsSoftware Design and Engineering',
#  '--Organic Chemistry',
#  '--Particle Physics',
#  '--Particle PhysicsQuantum Mechanics',
#  '--Particle PhysicsQuantum MechanicsRelativityTheoretical Physics',
#  '--Particle PhysicsQuantum MechanicsTheoretical Physics',
#  '--Particle PhysicsQuantum MechanicsThermodynamics',
#  '--Particle PhysicsTheoretical Physics',
#  '--Philosophy of Language',
#  '--Phonology',
#  '--PhonologySemanticsSyntax',
#  '--PhonologySyntax',
#  '--Photography',
#  '--Physical Chemistry',
#  '--Planetary Science',
#  '--Political Economy',
#  '--Political EconomyPublic Economics',
#  '--Political Philosophy',
#  '--Polymeric Materials',
#  '--Polymers',
#  '--Portuguese',
#  '--Process Control Systems',
#  '--Programming Languages',
#  '--Programming LanguagesSoftware Design and Engineering',
#  '--Programming LanguagesSoftware Design and EngineeringTheory of Computation',
#  '--Programming LanguagesTheory of Computation',
#  '--Propulsion Systems',
#  '--Proteomics',
#  '--Public Economics',
#  '--Public Policy',
#  '--Public PolicyRegional Politics',
#  '--Public PolicyScience and Technology PolicySecurity Studies',
#  '--Public PolicySecurity Studies',
#  '--Public PolicySocial Welfare',
#  '--Quantum Mechanics',
#  '--Quantum MechanicsTheoretical Physics',
#  '--Quantum MechanicsThermodynamics',
#  '--Radiological Engineering',
#  '--Regional Planning',
#  '--Regional PlanningTransportation Planning',
#  '--Regional PlanningTransportation PlanningUrban Planning',
#  '--Regional PlanningUrban Planning',
#  '--Regional Politics',
#  '--Relativity',
#  '--Rhetoric',
#  '--Robotics and Control Systems',
#  '--Robotics and Control SystemsSignal Processing',
#  '--Robotics and Control SystemsSignal ProcessingTelecommunications',
#  '--Science and Technology Policy',
#  '--Science and Technology PolicySecurity Studies',
#  '--Security Studies',
#  '--Semantics',
#  '--SemanticsSyntax',
#  '--Separation Processes',
#  '--Signal Processing',
#  '--Signal ProcessingTelecommunications',
#  '--Social Anthropology',
#  '--Social Justice',
#  '--Social Welfare',
#  '--Software Design and Engineering',
#  '--Solid Mechanics',
#  '--Spanish',
#  '--Stem Cells',
#  '--Structural Engineering',
#  '--Structural Mechanics',
#  '--Surveying',
#  '--Sustainability',
#  '--Syntax',
#  '--Synthetic Biology',
#  '--Systems Design',
#  '--Systems DesignSystems Optimization',
#  '--Systems Optimization',
#  '--Technical Writing',
#  '--Telecommunications',
#  '--Theater',
#  '--TheaterTheatrical Design',
#  '--Theatrical Design',
#  '--Theoretical Physics',
#  '--Theoretical PhysicsThermodynamics',
#  '--Theory of Computation',
#  '--Thermodynamics',
#  '--Transport Processes',
#  '--Transportation Engineering',
#  '--Transportation Planning',
#  '--Transportation PlanningUrban Planning',
#  '--Urban Planning',
#  '--World History'}
