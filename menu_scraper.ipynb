# %%
import requests
from bs4 import BeautifulSoup

from bs4.element import Comment
import pandas as pd

# %%
links = ['https://ocw.mit.edu/courses/1-00-introduction-to-computers-and-engineering-problem-solving-spring-2012/',
 'https://ocw.mit.edu/courses/1-010-uncertainty-in-engineering-fall-2008/',
 'https://ocw.mit.edu/courses/1-011-project-evaluation-spring-2011/',
 'https://ocw.mit.edu/courses/1-012-introduction-to-civil-engineering-design-spring-2002/',
 'https://ocw.mit.edu/courses/1-017-computing-and-data-analysis-for-environmental-applications-fall-2003/']

# %%
# Get Text from HTML
# https://stackoverflow.com/questions/1936466/how-to-scrape-only-visible-webpage-text-with-beautifulsoup
def tag_visible(element):
    if element.parent.name in ['style', 'script', 'head', 'title', 'meta', '[document]']:
        return False
    if isinstance(element, Comment):
        return False
    return True


def text_from_html(body):
    soup = BeautifulSoup(body, 'html.parser')
    texts = soup.findAll(text=True)
    visible_texts = filter(tag_visible, texts)  
    return u" ".join(t.strip() for t in visible_texts)

# %%
data = []

link_to_index = {}
index_to_link = {}

count = 0

for link in links:
    
    data_per_course = {}
    
    soup = BeautifulSoup(requests.get(link).text, 'html.parser')
    
    # Get all routes
    all_routes = soup.find_all('a', href=True)
    matched_routes = []
    for route in all_routes:
        if '/pages/' in route['href']:
            matched_routes.append('pages/' + route['href'].split('/pages/')[1])
    matched_routes.remove('pages/privacy-and-terms-of-use/')
    
    # Get all text from each route
    text_len = 0
    text_count = 0
    for route in matched_routes:
        url = link + route
        r = requests.get(url)
        text = text_from_html(r.content.decode('utf-8'))
        
        col_name = route.split('/')[1].rstrip('/')
        raw_text = ' '.join(text.split())
        
        data_per_course[col_name] = raw_text
        data_per_course[col_name + '_length'] = len(raw_text.split(' '))
        
        text_len += len(raw_text.split(' '))
        text_count += 1
        
    data_per_course['average_length'] = text_len / text_count
    
    data.append(data_per_course)
    
    link_to_index[link] = count
    index_to_link[count] = link
    count += 1

# %%
import json
with open('data.json', 'w') as f:
    json.dump(data, f)

# %%
df = pd.DataFrame(data)
df
# Out:
#                                             syllabus  syllabus_length  \
# 0  Browse Course Material Syllabus Instructor Ins...             1854
# 1  Browse Course Material Syllabus Calendar Lectu...              469
# 2  Browse Course Material Syllabus Subject Topics...              324
# 3  Browse Course Material Syllabus Calendar Readi...              348
# 4  Browse Course Material Syllabus Calendar Lectu...              413
#
#                                  instructor-insights  \
# 0  Browse Course Material Syllabus Instructor Ins...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    instructor-insights_length  \
# 0                      1290.0
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
#
#                                             readings  readings_length  \
# 0  Browse Course Material Syllabus Instructor Ins...            682.0
# 1                                                NaN              NaN
# 2  Browse Course Material Syllabus Subject Topics...            815.0
# 3  Browse Course Material Syllabus Calendar Readi...            378.0
# 4  Browse Course Material Syllabus Calendar Lectu...            725.0
#
#                                        lecture-notes  lecture-notes_length  \
# 0  Browse Course Material Syllabus Instructor Ins...                 917.0
# 1  Browse Course Material Syllabus Calendar Lectu...                 271.0
# 2  Browse Course Material Syllabus Subject Topics...                 429.0
# 3                                                NaN                   NaN
# 4  Browse Course Material Syllabus Calendar Lectu...                 401.0
#
#                                          recitations  recitations_length  ...  \
# 0  Browse Course Material Syllabus Instructor Ins...               311.0  ...
# 1                                                NaN                 NaN  ...
# 2                                                NaN                 NaN  ...
# 3                                                NaN                 NaN  ...
# 4  Browse Course Material Syllabus Calendar Lectu...               253.0  ...
#
#                                             calendar  calendar_length  \
# 0                                                NaN              NaN
# 1  Browse Course Material Syllabus Calendar Lectu...            680.0
# 2  Browse Course Material Syllabus Subject Topics...            513.0
# 3  Browse Course Material Syllabus Calendar Readi...            365.0
# 4  Browse Course Material Syllabus Calendar Lectu...            703.0
#
#                                 application-examples  \
# 0                                                NaN
# 1  Browse Course Material Syllabus Calendar Lectu...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    application-examples_length  \
# 0                          NaN
# 1                        498.0
# 2                          NaN
# 3                          NaN
# 4                          NaN
#
#                                   textbook-resources  \
# 0                                                NaN
# 1                                                NaN
# 2  Browse Course Material Syllabus Subject Topics...
# 3                                                NaN
# 4                                                NaN
#
#    textbook-resources_length  \
# 0                        NaN
# 1                        NaN
# 2                      389.0
# 3                        NaN
# 4                        NaN
#
#                                             projects projects_length  \
# 0                                                NaN             NaN
# 1                                                NaN             NaN
# 2  Browse Course Material Syllabus Subject Topics...           329.0
# 3  Browse Course Material Syllabus Calendar Readi...           317.0
# 4                                                NaN             NaN
#
#                                    related-resources related-resources_length
# 0                                                NaN                      NaN
# 1                                                NaN                      NaN
# 2                                                NaN                      NaN
# 3                                                NaN                      NaN
# 4  Browse Course Material Syllabus Calendar Lectu...                    874.0
#
# [5 rows x 27 columns]

# %%
link_to_index
# Out:
# {'https://ocw.mit.edu/courses/1-00-introduction-to-computers-and-engineering-problem-solving-spring-2012/': 0,
#  'https://ocw.mit.edu/courses/1-010-uncertainty-in-engineering-fall-2008/': 1,
#  'https://ocw.mit.edu/courses/1-011-project-evaluation-spring-2011/': 2,
#  'https://ocw.mit.edu/courses/1-012-introduction-to-civil-engineering-design-spring-2002/': 3,
#  'https://ocw.mit.edu/courses/1-017-computing-and-data-analysis-for-environmental-applications-fall-2003/': 4}

# %%
index_to_link
# Out:
# {0: 'https://ocw.mit.edu/courses/1-00-introduction-to-computers-and-engineering-problem-solving-spring-2012/',
#  1: 'https://ocw.mit.edu/courses/1-010-uncertainty-in-engineering-fall-2008/',
#  2: 'https://ocw.mit.edu/courses/1-011-project-evaluation-spring-2011/',
#  3: 'https://ocw.mit.edu/courses/1-012-introduction-to-civil-engineering-design-spring-2002/',
#  4: 'https://ocw.mit.edu/courses/1-017-computing-and-data-analysis-for-environmental-applications-fall-2003/'}
